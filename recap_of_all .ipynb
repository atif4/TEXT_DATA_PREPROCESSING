# %%
# EDA pamages 
import pandas as pd
import numpy as np

#hide earrings 
import warnings
warnings.filterwarnings('ignore')

# Data Viz pakages
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style

# %%
df = pd.read_csv("C:\\Users\\haier\\Downloads\\ds_salaries.csv")

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.drop("Unnamed: 0" , axis = 1 , inplace = True)

# %%
df.index.name='S:No' ; df.columns.name = 'Info'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %%
df.head(2)
# Out:
# Info  work_year experience_level employment_type                   job_title  \
# S:No
# 0          2020               MI              FT              Data Scientist
# 1          2020               SE              FT  Machine Learning Scientist
#
# Info  salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 0      70000             EUR          79833                 DE             0
# 1     260000             USD         260000                 JP             0
#
# Info company_location company_size
# S:No
# 0                  DE            L
# 1                  JP            S

# %%
df.describe()
# Out:
# Info     work_year        salary  salary_in_usd  remote_ratio
# count   607.000000  6.070000e+02     607.000000     607.00000
# mean   2021.405272  3.240001e+05  112297.869852      70.92257
# std       0.692133  1.544357e+06   70957.259411      40.70913
# min    2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    2022.000000  1.650000e+05  150000.000000     100.00000
# max    2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object', name='Info')

# %%
"""If the DataFrame’s columns are different dtypes,
the dtype of the values array will be
chosen to accommodate all of the columns:"""
df.values
# Out:
# array([[2020, 'MI', 'FT', ..., 0, 'DE', 'L'],
#        [2020, 'SE', 'FT', ..., 0, 'JP', 'S'],
#        [2020, 'SE', 'FT', ..., 50, 'GB', 'M'],
#        ...,
#        [2022, 'SE', 'FT', ..., 0, 'US', 'M'],
#        [2022, 'SE', 'FT', ..., 100, 'US', 'M'],
#        [2022, 'MI', 'FT', ..., 100, 'US', 'L']], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=607, step=1, name='S:No')

# %%
get_duplicates_dic = {}
def get_and_remove_duplicates(list_c_ids):
    for list_c_id in list_c_ids:
        dup_sum = df[list_c_id].duplicated().sum()
        get_duplicates_dic[list_c_id] = dup_sum
        print(list_c_id,'has',dup_sum,'values.')
        #drop_duplocates = df[list_c_id].drop_duplicates() # all duplicates values has been removed
        #print(b,drop_duplocates)

# %%
get_and_remove_duplicates(['work_year', 'experience_level', 'employment_type', 'job_title',
       'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
       'remote_ratio', 'company_location', 'company_size'])
# Out:
# work_year has 604 values.
# experience_level has 603 values.
# employment_type has 603 values.
# job_title has 557 values.
# salary has 335 values.
# salary_currency has 590 values.
# salary_in_usd has 238 values.
# employee_residence has 550 values.
# remote_ratio has 604 values.
# company_location has 557 values.
# company_size has 604 values.

# %%
print(get_duplicates_dic)
# Out:
# {'work_year': 604, 'experience_level': 603, 'employment_type': 603, 'job_title': 557, 'salary': 335, 'salary_currency': 590, 'salary_in_usd': 238, 'employee_residence': 550, 'remote_ratio': 604, 'company_location': 557, 'company_size': 604}

# %%
reindex_df = df.reindex(np.arange(1,607))

# %%
reindex_df
# Out:
# Info  work_year experience_level employment_type                   job_title  \
# S:No
# 1          2020               SE              FT  Machine Learning Scientist
# 2          2020               SE              FT           Big Data Engineer
# 3          2020               MI              FT        Product Data Analyst
# 4          2020               SE              FT   Machine Learning Engineer
# 5          2020               EN              FT                Data Analyst
# ...         ...              ...             ...                         ...
# 602        2022               SE              FT               Data Engineer
# 603        2022               SE              FT               Data Engineer
# 604        2022               SE              FT                Data Analyst
# 605        2022               SE              FT                Data Analyst
# 606        2022               MI              FT                AI Scientist
#
# ...

# %%
def get_unique(c_id):
    unique = reindex_df[c_id].unique()
    return unique
def get_value_count(c_id):
    value_count = reindex_df[c_id].value_counts()
    return value_count
def get_value_count_largest(c_id):
    value_count_largest = reindex_df[c_id].value_counts().nlargest(30)
    return value_count_largest

# %%
c_id = ['work_year', 'experience_level', 'employment_type',
       'job_title', 'salary', 'salary_currency', 'salary_in_usd',
       'employee_residence', 'remote_ratio', 'company_location',
       'company_size']
for i in c_id:
    length = get_unique(i)
    print(i,len(length))
    print(length)
# Out:
# work_year 3
# [2020 2021 2022]
# experience_level 4
# ['SE' 'MI' 'EN' 'EX']
# employment_type 4
# ['FT' 'CT' 'PT' 'FL']
# job_title 50
# ['Machine Learning Scientist' 'Big Data Engineer' 'Product Data Analyst'
#  'Machine Learning Engineer' 'Data Analyst' 'Lead Data Scientist'
#  'Data Scientist' 'Business Data Analyst' 'Lead Data Engineer'
#  'Lead Data Analyst' 'Data Engineer' 'Data Science Consultant'
#  'BI Data Analyst' 'Director of Data Science' 'Research Scientist'
#  'Machine Learning Manager' 'Data Engineering Manager'
#  'Machine Learning Infrastructure Engineer' 'ML Engineer' 'AI Scientist'
#  'Computer Vision Engineer' 'Principal Data Scientist'
#  'Data Science Manager' 'Head of Data' '3D Computer Vision Researcher'
#  'Data Analytics Engineer' 'Applied Data Scientist'
#  'Marketing Data Analyst' 'Cloud Data Engineer' 'Financial Data Analyst'
#  'Computer Vision Software Engineer' 'Director of Data Engineering'
#  'Data Science Engineer' 'Principal Data Engineer'
# ...

# %%
reindex_df.isnull().sum()
# Out:
# Info
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
reindex_df.describe()
# Out:
# Info     work_year        salary  salary_in_usd  remote_ratio
# count   606.000000  6.060000e+02     606.000000    606.000000
# mean   2021.407591  3.244192e+05  112351.442244     71.039604
# std       0.690341  1.545599e+06   71003.590724     40.640432
# min    2020.000000  4.000000e+03    2859.000000      0.000000
# 25%    2021.000000  7.000000e+04   62726.000000     50.000000
# 50%    2022.000000  1.150000e+05  101835.000000    100.000000
# 75%    2022.000000  1.650000e+05  150000.000000    100.000000
# max    2022.000000  3.040000e+07  600000.000000    100.000000

# %%
small = reindex_df[(reindex_df['work_year'] == 2020) & (reindex_df['company_size'] == 'S') ]

# %%
small.sort_index()
# Out:
# Info  work_year experience_level employment_type                   job_title  \
# S:No
# 1          2020               SE              FT  Machine Learning Scientist
# 3          2020               MI              FT        Product Data Analyst
# 6          2020               SE              FT         Lead Data Scientist
# 9          2020               SE              FT          Lead Data Engineer
# 10         2020               EN              FT              Data Scientist
# 16         2020               EN              FT               Data Engineer
# 17         2020               SE              FT           Big Data Engineer
# 27         2020               SE              FT               Data Engineer
# 30         2020               MI              FT    Data Engineering Manager
# 38         2020               EN              FT                Data Analyst
# 39         2020               EN              FT   Machine Learning Engineer
# ...

# %%
small.sort_values('salary_currency')
# Out:
# Info  work_year experience_level employment_type                   job_title  \
# S:No
# 52         2020               EN              FT                AI Scientist
# 45         2020               EN              PT                 ML Engineer
# 69         2020               SE              FT              Data Scientist
# 66         2020               EN              FT              Data Scientist
# 65         2020               EN              FT              Data Scientist
# 64         2020               SE              FT   Machine Learning Engineer
# 62         2020               EN              PT              Data Scientist
# 70         2020               MI              FT              Data Scientist
# 71         2020               MI              FT              Data Scientist
# 17         2020               SE              FT           Big Data Engineer
# 10         2020               EN              FT              Data Scientist
# ...

# %%
sorted(set(small))
# Out:
# ['company_location',
#  'company_size',
#  'employee_residence',
#  'employment_type',
#  'experience_level',
#  'job_title',
#  'remote_ratio',
#  'salary',
#  'salary_currency',
#  'salary_in_usd',
#  'work_year']

# %%
intersection_8_10 = set(reindex_df['employee_residence']) & set(reindex_df['company_location'])
intersection_8_10
# Out:
# {'AE',
#  'AT',
#  'AU',
#  'BE',
#  'BR',
#  'CA',
#  'CH',
#  'CL',
#  'CN',
#  'CO',
#  'CZ',
#  'DE',
#  'DK',
#  'DZ',
#  'EE',
#  'ES',
#  'FR',
#  'GB',
#  'GR',
#  'HN',
#  'HR',
#  'HU',
#  'IE',
#  'IN',
#  'IQ',
#  'IR',
#  'IT',
#  'JP',
#  'KE',
#  'LU',
#  'MD',
#  'MT',
#  'MX',
#  'MY',
#  'NG',
#  'NL',
#  'NZ',
#  'PK',
#  'PL',
#  'PT',
#  'RO',
#  'RU',
#  'SG',
#  'SI',
#  'TR',
#  'UA',
#  'US',
#  'VN'}

# %%
#Compute the sorted, common elements in x and y
np.intersect1d(reindex_df['employee_residence'],reindex_df['company_location'])
# Out:
# array(['AE', 'AT', 'AU', 'BE', 'BR', 'CA', 'CH', 'CL', 'CN', 'CO', 'CZ',
#        'DE', 'DK', 'DZ', 'EE', 'ES', 'FR', 'GB', 'GR', 'HN', 'HR', 'HU',
#        'IE', 'IN', 'IQ', 'IR', 'IT', 'JP', 'KE', 'LU', 'MD', 'MT', 'MX',
#        'MY', 'NG', 'NL', 'NZ', 'PK', 'PL', 'PT', 'RO', 'RU', 'SG', 'SI',
#        'TR', 'UA', 'US', 'VN'], dtype=object)

# %%
#Compute the sorted union of elements
np.union1d(reindex_df['employee_residence'],reindex_df['company_location'])
# Out:
# array(['AE', 'AR', 'AS', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH',
#        'CL', 'CN', 'CO', 'CZ', 'DE', 'DK', 'DZ', 'EE', 'ES', 'FR', 'GB',
#        'GR', 'HK', 'HN', 'HR', 'HU', 'IE', 'IL', 'IN', 'IQ', 'IR', 'IT',
#        'JE', 'JP', 'KE', 'LU', 'MD', 'MT', 'MX', 'MY', 'NG', 'NL', 'NZ',
#        'PH', 'PK', 'PL', 'PR', 'PT', 'RO', 'RS', 'RU', 'SG', 'SI', 'TN',
#        'TR', 'UA', 'US', 'VN'], dtype=object)

# %%
#Compute a boolean array indicating whether each element of x is contained in y
np.in1d(reindex_df['employee_residence'],reindex_df['company_location'])
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
#Set difference, elements in x that are not in y
np.setdiff1d(reindex_df['employee_residence'],reindex_df['company_location'])
# Out:
# array(['AR', 'BG', 'BO', 'HK', 'JE', 'PH', 'PR', 'RS', 'TN'], dtype=object)

# %%
#Set symmetric differences; elements that are in either of the arrays, but not both
np.setxor1d(reindex_df['employee_residence'],reindex_df['company_location'])
# Out:
# array(['AR', 'AS', 'BG', 'BO', 'HK', 'IL', 'JE', 'PH', 'PR', 'RS', 'TN'],
#       dtype=object)

# %%
#the dot() function performs the inner product of vectors (without complex conjugation).
reindex_df['salary'].dot(reindex_df['salary_in_usd'])
# Out:
# 16507844068181

# %%
np.dot(reindex_df['salary'],reindex_df['salary_in_usd'])
# Out:
# 16507844068181

# %%
np.dot(reindex_df['salary'],np.ones(606))
# Out:
# 196598038.0

# %%
from numpy.linalg import inv, qr

# %%
d2 = reindex_df['salary'],reindex_df['salary_currency']

# %%
d2
# Out:
# (S:No
#  1      260000
#  2       85000
#  3       20000
#  4      150000
#  5       72000
#          ...
#  602    154000
#  603    126000
#  604    129000
#  605    150000
#  606    200000
#  Name: salary, Length: 606, dtype: int64, S:No
#  1      USD
#  2      GBP
#  3      USD
#  4      USD
#  5      USD
#        ...
#  602    USD
#  603    USD
#  604    USD
#  605    USD
#  606    USD
#  Name: salary_currency, Length: 606, dtype: object)

# %%
import random
position = 0
walk = [position]
steps = 1000
for i in range(steps):
    step = 1 if random.randint(0, 1) else -1
    position += step
    walk.append(position)

# %%
walk
# Out:
# [0,
#  1,
#  0,
#  1,
#  0,
#  1,
#  2,
#  1,
#  0,
#  -1,
#  0,
#  1,
#  0,
#  1,
#  0,
#  1,
#  2,
#  1,
#  0,
#  1,
#  0,
#  -1,
#  0,
#  -1,
#  0,
#  -1,
#  -2,
#  -3,
#  -2,
#  -1,
#  0,
#  1,
#  2,
#  3,
#  4,
#  3,
#  2,
#  1,
#  0,
#  1,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  0,
#  -1,
#  0,
#  1,
#  2,
#  3,
#  2,
#  3,
#  4,
#  5,
#  6,
#  5,
#  6,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  6,
#  7,
#  8,
#  7,
#  8,
#  9,
#  10,
#  9,
#  10,
#  9,
#  8,
#  7,
#  8,
#  9,
#  8,
#  7,
#  8,
#  9,
#  8,
#  7,
#  8,
#  9,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  9,
#  8,
#  9,
#  10,
#  11,
#  10,
#  9,
#  8,
#  9,
#  10,
#  11,
#  10,
#  11,
#  12,
#  13,
#  12,
#  13,
#  14,
#  13,
#  12,
#  11,
#  10,
#  11,
#  12,
#  11,
#  12,
#  13,
#  14,
#  15,
#  14,
#  15,
#  16,
#  15,
#  16,
#  17,
#  16,
#  15,
#  14,
#  13,
#  14,
#  15,
#  14,
#  13,
#  12,
#  13,
#  14,
#  15,
#  16,
#  17,
#  18,
#  19,
#  18,
#  19,
#  18,
#  17,
#  18,
#  19,
#  20,
#  21,
# ...

# %%
plt.plot(walk[:100])

# %%
data_analyst_se = reindex_df[(reindex_df['experience_level'] == "SE") & (reindex_df['job_title'] == "Data Analyst")]

# %%
data_analyst_se
# Out:
# Info  work_year experience_level employment_type     job_title  salary  \
# S:No
# 89         2021               SE              FT  Data Analyst   80000
# 229        2021               SE              FT  Data Analyst   90000
# 233        2021               SE              FT  Data Analyst  200000
# 261        2021               SE              FT  Data Analyst   54000
# 290        2022               SE              FT  Data Analyst  155000
# 291        2022               SE              FT  Data Analyst  120600
# 296        2022               SE              FT  Data Analyst  102100
# 297        2022               SE              FT  Data Analyst   84900
# 305        2022               SE              FT  Data Analyst   99000
# 306        2022               SE              FT  Data Analyst  116000
# 318        2022               SE              FT  Data Analyst   90320
# 325        2022               SE              FT  Data Analyst  124190
# ...

# %%
data_analyst_mi = reindex_df[(reindex_df['experience_level'] == "MI") & (reindex_df['job_title'] == "Data Analyst")]

# %%
data_analyst_mi
# Out:
# Info  work_year experience_level employment_type     job_title  salary  \
# S:No
# 14         2020               MI              FT  Data Analyst   85000
# 15         2020               MI              FT  Data Analyst    8000
# 34         2020               MI              FT  Data Analyst   41000
# 100        2021               MI              FT  Data Analyst   75000
# 103        2021               MI              FT  Data Analyst   62000
# 105        2021               MI              FT  Data Analyst   37456
# 135        2021               MI              FT  Data Analyst   90000
# 140        2021               MI              FT  Data Analyst  135000
# 241        2021               MI              FT  Data Analyst   80000
# 254        2021               MI              FT  Data Analyst   93000
# 307        2022               MI              FT  Data Analyst  106260
# 308        2022               MI              FT  Data Analyst  126500
# ...

# %%
data_analyst_en = reindex_df[(reindex_df['experience_level'] == "EN") & (reindex_df['job_title'] == "Data Analyst")]

# %%
data_analyst_en
# Out:
# Info  work_year experience_level employment_type     job_title  salary  \
# S:No
# 5          2020               EN              FT  Data Analyst   72000
# 38         2020               EN              FT  Data Analyst   10000
# 50         2020               EN              FT  Data Analyst  450000
# 51         2020               EN              FT  Data Analyst   91000
# 79         2021               EN              FT  Data Analyst   80000
# 86         2021               EN              FT  Data Analyst   50000
# 118        2021               EN              FT  Data Analyst   90000
# 122        2021               EN              FT  Data Analyst   50000
# 124        2021               EN              PT  Data Analyst    8760
# 172        2021               EN              FT  Data Analyst   60000
# 600        2022               EN              FT  Data Analyst   67000
# 601        2022               EN              FT  Data Analyst   52000
#
# ...

# %%
data_analyst_ex = reindex_df[(reindex_df['experience_level'] == "EX") & (reindex_df['job_title'] == "Data Analyst")]

# %%
data_analyst_ex
# Out:
# Info  work_year experience_level employment_type     job_title  salary  \
# S:No
# 326        2022               EX              FT  Data Analyst  130000
# 327        2022               EX              FT  Data Analyst  110000
#
# Info salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 326              USD         130000                 US           100
# 327              USD         110000                 US           100
#
# Info company_location company_size
# S:No
# 326                US            M
# 327                US            M

# %%
#it is work for col
reindex_df[['work_year']]
# Out:
# Info  work_year
# S:No
# 1          2020
# 2          2020
# 3          2020
# 4          2020
# 5          2020
# ...         ...
# 602        2022
# 603        2022
# 604        2022
# 605        2022
# 606        2022
#
# [606 rows x 1 columns]

# %%
#it is work for col
reindex_df[['work_year','salary']]
# Out:
# Info  work_year  salary
# S:No
# 1          2020  260000
# 2          2020   85000
# 3          2020   20000
# 4          2020  150000
# 5          2020   72000
# ...         ...     ...
# 602        2022  154000
# 603        2022  126000
# 604        2022  129000
# 605        2022  150000
# 606        2022  200000
#
# [606 rows x 2 columns]

# %%
#here it pick rows only
reindex_df[:4]
# Out:
# Info  work_year experience_level employment_type                   job_title  \
# S:No
# 1          2020               SE              FT  Machine Learning Scientist
# 2          2020               SE              FT           Big Data Engineer
# 3          2020               MI              FT        Product Data Analyst
# 4          2020               SE              FT   Machine Learning Engineer
#
# Info  salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 1     260000             USD         260000                 JP             0
# 2      85000             GBP         109024                 GB            50
# 3      20000             USD          20000                 HN             0
# 4     150000             USD         150000                 US            50
#
# Info company_location company_size
# S:No
# 1                  JP            S
# 2                  GB            M
# 3                  HN            S
# ...

# %%
reindex_df[reindex_df['salary'] == 150000]
# Out:
# Info  work_year experience_level employment_type  \
# S:No
# 4          2020               SE              FT
# 73         2021               EX              FT
# 101        2021               SE              FT
# 108        2021               SE              FT
# 142        2021               SE              FT
# 151        2021               MI              FT
# 169        2021               MI              FT
# 295        2022               MI              FT
# 356        2022               SE              FT
# 375        2022               EX              FT
# 492        2022               MI              FT
# 510        2022               EN              FT
# 593        2022               SE              FT
# 605        2022               SE              FT
#
# Info                          job_title  salary salary_currency  \
# S:No
# 4             Machine Learning Engineer  150000             USD
# 73                      BI Data Analyst  150000             USD
# ...

# %%
#Selection with loc and iloc
#here it 1st put row no: then cols
reindex_df.loc[606:,['work_year','salary']]
# Out:
# Info  work_year  salary
# S:No
# 606        2022  200000

# %%
reindex_df.iloc[605:606, [0,4]]
# Out:
# Info  work_year  salary
# S:No
# 606        2022  200000

# %%
#here it bring elements of reindex_df of row 2
reindex_df.loc[2]
# Out:
# Info
# work_year                          2020
# experience_level                     SE
# employment_type                      FT
# job_title             Big Data Engineer
# salary                            85000
# salary_currency                     GBP
# salary_in_usd                    109024
# employee_residence                   GB
# remote_ratio                         50
# company_location                     GB
# company_size                          M
# Name: 2, dtype: object

# %%
#here it bring elements of reindex_df of row 2
reindex_df.iloc[2]
# Out:
# Info
# work_year                             2020
# experience_level                        MI
# employment_type                         FT
# job_title             Product Data Analyst
# salary                               20000
# salary_currency                        USD
# salary_in_usd                        20000
# employee_residence                      HN
# remote_ratio                             0
# company_location                        HN
# company_size                             S
# Name: 3, dtype: object

# %%
reindex_df.loc[2:2]
# Out:
# Info  work_year experience_level employment_type          job_title  salary  \
# S:No
# 2          2020               SE              FT  Big Data Engineer   85000
#
# Info salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 2                GBP         109024                 GB            50
#
# Info company_location company_size
# S:No
# 2                  GB            M

# %%
reindex_df.iloc[[1, 2], [3, 0, 1]]
# Out:
# Info             job_title  work_year experience_level
# S:No
# 2        Big Data Engineer       2020               SE
# 3     Product Data Analyst       2020               MI

# %%
reindex_df.loc[:4,'salary']
# Out:
# S:No
# 1    260000
# 2     85000
# 3     20000
# 4    150000
# Name: salary, dtype: int64

# %%
#Selection with loc and iloc
reindex_df.loc[2:3,['salary','salary_currency']]
# Out:
# Info  salary salary_currency
# S:No
# 2      85000             GBP
# 3      20000             USD

# %%
#all rows but upto colume 5th
reindex_df.iloc[:,:5].head()
# Out:
# Info  work_year experience_level employment_type                   job_title  \
# S:No
# 1          2020               SE              FT  Machine Learning Scientist
# 2          2020               SE              FT           Big Data Engineer
# 3          2020               MI              FT        Product Data Analyst
# 4          2020               SE              FT   Machine Learning Engineer
# 5          2020               EN              FT                Data Analyst
#
# Info  salary
# S:No
# 1     260000
# 2      85000
# 3      20000
# 4     150000
# 5      72000

# %%
#all rows but upto colume 5th in addOrion a condition 
reindex_df.iloc[:,:5][reindex_df.salary == 72000]
# Out:
# Info  work_year experience_level employment_type     job_title  salary
# S:No
# 5          2020               EN              FT  Data Analyst   72000

# %%
a = reindex_df.iloc[:3,[4,0,5,3]]

# %%
a
# Out:
# Info  salary  work_year salary_currency                   job_title
# S:No
# 1     260000       2020             USD  Machine Learning Scientist
# 2      85000       2020             GBP           Big Data Engineer
# 3      20000       2020             USD        Product Data Analyst

# %%
reindex_df.loc[4:4]
# Out:
# Info  work_year experience_level employment_type                  job_title  \
# S:No
# 4          2020               SE              FT  Machine Learning Engineer
#
# Info  salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 4     150000             USD         150000                 US            50
#
# Info company_location company_size
# S:No
# 4                  US            L

# %%
reindex_df.iloc[[2,3],[3,0,8]]
# Out:
# Info                  job_title  work_year  remote_ratio
# S:No
# 3          Product Data Analyst       2020             0
# 4     Machine Learning Engineer       2020            50

# %%
reindex_df.iloc[:3,7]
# Out:
# S:No
# 1    JP
# 2    GB
# 3    HN
# Name: employee_residence, dtype: object

# %%
reindex_df.iloc[:,:3][reindex_df['experience_level']=='SE']
# Out:
# Info  work_year experience_level employment_type
# S:No
# 1          2020               SE              FT
# 2          2020               SE              FT
# 4          2020               SE              FT
# 6          2020               SE              FT
# 9          2020               SE              FT
# ...         ...              ...             ...
# 597        2022               SE              FT
# 602        2022               SE              FT
# 603        2022               SE              FT
# 604        2022               SE              FT
# 605        2022               SE              FT
#
# [280 rows x 3 columns]

# %%
reindex_df['salary']+reindex_df['work_year']
# Out:
# S:No
# 1      262020
# 2       87020
# 3       22020
# 4      152020
# 5       74020
#         ...
# 602    156022
# 603    128022
# 604    131022
# 605    152022
# 606    202022
# Length: 606, dtype: int64

# %%
reindex_df['experience_level']+" "+reindex_df['employment_type']
# Out:
# S:No
# 1      SE FT
# 2      SE FT
# 3      MI FT
# 4      SE FT
# 5      EN FT
#        ...
# 602    SE FT
# 603    SE FT
# 604    SE FT
# 605    SE FT
# 606    MI FT
# Length: 606, dtype: object

# %%
reindex_df['experience_employment'] = reindex_df['experience_level']+" "+reindex_df['employment_type']

# %%
reindex_df
# Out:
# Info  work_year experience_level employment_type                   job_title  \
# S:No
# 1          2020               SE              FT  Machine Learning Scientist
# 2          2020               SE              FT           Big Data Engineer
# 3          2020               MI              FT        Product Data Analyst
# 4          2020               SE              FT   Machine Learning Engineer
# 5          2020               EN              FT                Data Analyst
# ...         ...              ...             ...                         ...
# 602        2022               SE              FT               Data Engineer
# 603        2022               SE              FT               Data Engineer
# 604        2022               SE              FT                Data Analyst
# 605        2022               SE              FT                Data Analyst
# 606        2022               MI              FT                AI Scientist
#
# ...

# %%
reindex_df['extra_salary_in_dollers'] = reindex_df['salary_in_usd'] - reindex_df['salary']

# %%
reindex_df[reindex_df['extra_salary_in_dollers'] != 0]
# Out:
# Info  work_year experience_level employment_type          job_title    salary  \
# S:No
# 2          2020               SE              FT  Big Data Engineer     85000
# 7          2020               MI              FT     Data Scientist  11000000
# 10         2020               EN              FT     Data Scientist     45000
# 11         2020               MI              FT     Data Scientist   3000000
# 12         2020               EN              FT     Data Scientist     35000
# ...         ...              ...             ...                ...       ...
# 517        2022               MI              FT      Data Engineer     62000
# 518        2022               MI              FT     Data Scientist    115000
# 520        2022               MI              FT     Data Scientist     88000
# 567        2022               MI              FT       Data Analyst     50000
# 586        2022               MI              FT       Data Analyst     35000
#
# ...

# %%
additional_salary = reindex_df[(reindex_df['extra_salary_in_dollers'] != 0) & (reindex_df['extra_salary_in_dollers'] >  0)]

# %%
currence_and_salary = additional_salary[['salary_currency','extra_salary_in_dollers']]

# %%
additional_salary.sort_values(['extra_salary_in_dollers'])
# Out:
# Info  work_year experience_level employment_type  \
# S:No
# 124        2021               EN              PT
# 45         2020               EN              PT
# 449        2022               EN              FT
# 62         2020               EN              PT
# 489        2022               EN              CT
# ...         ...              ...             ...
# 389        2022               MI              FT
# 123        2021               EN              FT
# 111        2021               SE              FT
# 221        2021               MI              FT
# 474        2022               MI              FT
#
# Info                           job_title  salary salary_currency  \
# S:No
# 124                         Data Analyst    8760             EUR
# 45                           ML Engineer   14000             EUR
# 449                          ML Engineer   20000             EUR
# 62                        Data Scientist   19000             EUR
# ...

# %%
sorted_df[['job_title','remote_ratio','extra_salary_in_dollers']]
# Out:
# Info                           job_title  remote_ratio  \
# S:No
# 124                         Data Analyst            50
# 45                           ML Engineer           100
# 449                          ML Engineer           100
# 62                        Data Scientist            50
# 489   Applied Machine Learning Scientist           100
# ...                                  ...           ...
# 389            Machine Learning Engineer             0
# 123               Applied Data Scientist             0
# 111         Director of Data Engineering           100
# 221                       Data Scientist            50
# 474                       Data Scientist             0
#
# Info  extra_salary_in_dollers
# S:No
# 124                      1594
# 45                       1966
# 449                      1983
# 62                       2669
# 489                      2875
# ...                       ...
# 389                     29333
# 123                     30037
# ...

# %% [raw]
# def get_unique(c_id):
#     unique = sorted_df[c_id].unique()
#     return unique

# %% [raw]
# c_id = ['job_title','remote_ratio','extra_salary_in_dollers']
# for i in c_id:
#     print(get_unique(i))

# %%
def get_graph(title,f_name):
        # a scatter plot comparing num_children and num_pets
        plt.figure(figsize=(20,7))
        plt.xticks(rotation= 90)
        plt.title(title.upper())
        plot_info = sns.barplot(x = 'job_title' , y = 'extra_salary_in_dollers' ,data = sorted_df, hue='remote_ratio')
        #dots per inch = dpi
        """The keyword argument dpi= specifies how many dots per inch (image resolution) are in the saved image. 
        dpi=72 is fine for web images.dpi=300 is better for an image designed to go in a written report or .pdf document
        The keyword argument bbox_inches='tight' is optional. If the axis labels in the plot are cut off in the saved image,
        set bbox_inches='tight'"""
        plt.savefig(f_name, dpi=300, bbox_inches='tight')
        plt.show()
get_graph('additional_salary','sorted_df')

# %%
sorted_df[(sorted_df['remote_ratio'] == 0) & (sorted_df['job_title'] == 'Data Analyst')]
# Out:
# Info  work_year experience_level employment_type     job_title  salary  \
# S:No
# 586        2022               MI              FT  Data Analyst   35000
# 567        2022               MI              FT  Data Analyst   50000
#
# Info salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 586              GBP          45807                 GB             0
# 567              GBP          65438                 GB             0
#
# Info company_location company_size experience_employment  \
# S:No
# 586                GB            M                 MI FT
# 567                GB            M                 MI FT
#
# Info  extra_salary_in_dollers
# S:No
# 586                     10807
# 567                     15438

# %%
sorted_df[(sorted_df['remote_ratio'] == 50) & (sorted_df['job_title'] == 'Data Analyst')]
# Out:
# Info  work_year experience_level employment_type     job_title  salary  \
# S:No
# 124        2021               EN              PT  Data Analyst    8760
# 34         2020               MI              FT  Data Analyst   41000
# 86         2021               EN              FT  Data Analyst   50000
# 261        2021               SE              FT  Data Analyst   54000
# 105        2021               MI              FT  Data Analyst   37456
#
# Info salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 124              EUR          10354                 ES            50
# 34               EUR          46759                 FR            50
# 86               EUR          59102                 FR            50
# 261              EUR          63831                 DE            50
# 105              GBP          51519                 GB            50
#
# Info company_location company_size experience_employment  \
# S:No
# ...

# %%
sorted_df[(sorted_df['remote_ratio'] == 50+50) & (sorted_df['job_title'] == 'Data Analyst')]
# Out:
# Info  work_year experience_level employment_type     job_title  salary  \
# S:No
# 441        2022               MI              FT  Data Analyst   30000
# 431        2022               MI              FT  Data Analyst   30000
# 430        2022               MI              FT  Data Analyst   40000
# 440        2022               MI              FT  Data Analyst   40000
# 429        2022               MI              FT  Data Analyst   30000
# 408        2022               MI              FT  Data Analyst   40000
#
# Info salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 441              EUR          32974                 GR           100
# 431              EUR          32974                 ES           100
# 430              EUR          43966                 ES           100
# 440              EUR          43966                 GR           100
# 429              GBP          39263                 GB           100
# ...

# %%
sorted_df[(sorted_df['remote_ratio'] == 100) & (sorted_df['job_title'] == 'ML Engineer')]
# Out:
# Info  work_year experience_level employment_type    job_title  salary  \
# S:No
# 45         2020               EN              PT  ML Engineer   14000
# 449        2022               EN              FT  ML Engineer   20000
#
# Info salary_currency  salary_in_usd employee_residence  remote_ratio  \
# S:No
# 45               EUR          15966                 DE           100
# 449              EUR          21983                 PT           100
#
# Info company_location company_size experience_employment  \
# S:No
# 45                 DE            S                 EN PT
# 449                PT            L                 EN FT
#
# Info  extra_salary_in_dollers
# S:No
# 45                       1966
# 449                      1983

# %%
less_salary = reindex_df[(reindex_df['extra_salary_in_dollers'] <  0)]

# %%
currency_and_loss_salary = less_salary[['salary_currency','extra_salary_in_dollers']]

# %%
sorted_df_less = less_salary.sort_values(['extra_salary_in_dollers'])

# %%
less_salary[['job_title','remote_ratio','extra_salary_in_dollers']]
# Out:
# Info                  job_title  remote_ratio  extra_salary_in_dollers
# S:No
# 7                Data Scientist            50                -10964265
# 11               Data Scientist             0                 -2959519
# 16                Data Engineer           100                 -4408311
# 18      Data Science Consultant            50                  -417293
# 20    Machine Learning Engineer             0                  -255669
# ...                         ...           ...                      ...
# 499              Data Scientist           100                   -14104
# 503   Machine Learning Engineer           100                   -33575
# 505              Data Scientist            50                   -33297
# 511       Business Data Analyst            50                   -19088
# 520              Data Scientist           100                   -18664
#
# [69 rows x 3 columns]

# %%
def get_graph(title,f_name):
        # a scatter plot comparing num_children and num_pets
        plt.figure(figsize=(20,7))
        plt.xticks(rotation= 90)
        plt.title(title.upper())
        plot_info = sns.barplot(x = 'job_title' , y = 'extra_salary_in_dollers' ,data = sorted_df_less)
        #dots per inch = dpi
        """The keyword argument dpi= specifies how many dots per inch (image resolution) are in the saved image. 
        dpi=72 is fine for web images.dpi=300 is better for an image designed to go in a written report or .pdf document
        The keyword argument bbox_inches='tight' is optional. If the axis labels in the plot are cut off in the saved image,
        set bbox_inches='tight'"""
        plt.savefig(f_name, dpi=300, bbox_inches='tight')
        plt.show()
get_graph('less_salary','sorted_df_less')

# %%
no_variation = reindex_df[(reindex_df['extra_salary_in_dollers'] == 0)]

# %%
no_variation[['salary_currency','extra_salary_in_dollers']]
# Out:
# Info salary_currency  extra_salary_in_dollers
# S:No
# 1                USD                        0
# 3                USD                        0
# 4                USD                        0
# 5                USD                        0
# 6                USD                        0
# ...              ...                      ...
# 602              USD                        0
# 603              USD                        0
# 604              USD                        0
# 605              USD                        0
# 606              USD                        0
#
# [398 rows x 2 columns]

# %%
additional_salary['salary_currency'].unique()
# Out:
# array(['GBP', 'EUR', 'CHF'], dtype=object)

# %%
less_salary['salary_currency'].unique()
# Out:
# array(['HUF', 'INR', 'JPY', 'CNY', 'MXN', 'CAD', 'DKK', 'PLN', 'SGD',
#        'CLP', 'BRL', 'TRY', 'AUD'], dtype=object)

# %%
no_variation['salary_currency'].unique()
# Out:
# array(['USD'], dtype=object)
